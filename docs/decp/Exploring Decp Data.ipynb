# %% [markdown]
# # Exploring Marches (DECP) Data

# %%
import pandas as pd
import psycopg2
import configparser
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Initiate a connection to Redshift
# using a local config file

# %%
config = configparser.ConfigParser()
project_config_path = '/Users/paulogier/Library/Preferences/PyCharm2019.3/scratches/capstone.cfg'
config.read(project_config_path)
DWH_HOST = config.get("DB", "DB_HOST")
DWH_DB = config.get("DB", "DB_NAME")
DWH_DB_USER = config.get("DB", "DB_USER")
DWH_DB_PASSWORD = config.get("DB", "DB_PASSWORD")
DWH_PORT = config.get("DB", "DB_PORT")
conn = psycopg2.connect(host =DWH_HOST ,database = DWH_DB, user=DWH_DB_USER, password=DWH_DB_PASSWORD, port=DWH_PORT)
conn.autocommit = True
print(conn.status)
# Out:
# 1

# %% [markdown]
# ## Exploring marches

# %%
marches = pd.read_sql('SELECT * FROM dwh.decp_marches;', conn)

# %%
marches.sample(5)
# Out:
#                               decp_uid                source  \
# 94014   130016421000132020151021303200     data.gouv.fr_aife
# 154118  2659067350001320192020T0531100     data.gouv.fr_aife
# 133275      214502346000152019V1935000      data.gouv.fr_pes
# 219400         34749837000027201914900  marches-publics.info
# 149323     218201218000112019190040900  marches-publics.info
#
#                  decp_id    type  nature              procedure  \
# 94014   2020151021303200  Marché  Marché                   None
# 154118  20192020T0531100  Marché  Marché  Appel d'offres ouvert
# 133275      2019V1935000  Marché  Marché      Procédure adaptée
# 219400         201914900  Marché  Marché      Procédure adaptée
# 149323     2019190040900  Marché  Marché      Procédure adaptée
#
#                                                     objet     codecpv  \
# 94014   Pièces pour pompes, compresseurs, machines ou ...    42124000
# 154118  Le marché est composé de 10 lots. 2181 lot 7 :...    45000000
# 133275        V19350 REMPLACEMENT TGBT 2 CENTRE MUNICIPAL  31214500-4
# 219400  19DC001 TALENSAC « Rue du Centre » - 11 logeme...    71200000
# 149323  Numéro de la consultation : 19/004 <br />EXTEN...    45261000
#
#         dureemois datenotification datepublicationdonnees   montant  \
# 94014           1       2020-09-30             2020-09-30   1063.50
# 154118         41       2019-12-11             2019-12-11  61629.78
# 133275          4       2019-08-21             2019-08-29  68316.62
# 219400         36       2019-07-08             2019-07-08  72072.00
# 149323         15       2019-06-21             2019-06-27  78596.00
#
#                     formeprix     acheteur_id  \
# 94014                   Ferme  13001642100013
# 154118  Ferme et actualisable  26590673500013
# 133275              Révisable  21450234600015
# 219400                  Ferme  34749837000027
# 149323              Révisable  21820121800011
#
#                                             acheteur_name
# 94014   Ministère des armées - Structure Spécialisée d...
# 154118                                   CH VALENCIENNES
# 133275                                    VILLE D'ORLEANS
# 219400                                             NEOTOA
# 149323                                 VILLE DE MONTAUBAN

# %% [markdown]
# ### Number of rows

# %%
marches.shape[0]
# Out:
# 232648

# %% [markdown]
# ### null values

# %%
(marches.isnull().sum(axis=0)/marches.shape[0]).sort_values(ascending=False)
# Out:
# procedure                 0.047196
# formeprix                 0.020611
# datenotification          0.010956
# nature                    0.006503
# acheteur_name             0.003563
# codecpv                   0.002729
# acheteur_id               0.001272
# montant                   0.000920
# objet                     0.000524
# decp_id                   0.000077
# datepublicationdonnees    0.000017
# dureemois                 0.000000
# type                      0.000000
# source                    0.000000
# decp_uid                  0.000000
# dtype: float64

# %% [markdown]
# ### Primary Key

# %%
if marches['decp_uid'].nunique()/marches.shape[0] ==1:
    print('decp_uid has unique values')
# Out:
# decp_uid has unique values

# %% [markdown]
# ### Amount

# %%
marches['montant'].describe()
# Out:
# count    2.324340e+05
# mean     1.015810e+08
# std      2.940726e+10
# min      0.000000e+00
# 25%      3.164703e+04
# 50%      8.420000e+04
# 75%      2.410000e+05
# max      1.000000e+13
# Name: montant, dtype: float64

# %% [markdown]
# Some marches have a value of 100 million euros, which is probably a typo.
# Some marches have null values

# %%
marches['montant'].plot(kind='box');

# %% [markdown]
# The picture confirms the outlier status of the points > 100 million euros

# %%
marches.loc[marches['montant']>= 10**8]
# Out:
#                               decp_uid             source           decp_id  \
# 119     1100020110004420202021T0490000  data.gouv.fr_aife  20202021T0490000
# 703     1300017040058920202020T0266800  data.gouv.fr_aife  20202020T0266800
# 1408    1300017040058920202020T0266700  data.gouv.fr_aife  20202020T0266700
# 1463    1300019020001920202020T0679200  data.gouv.fr_aife  20202020T0679200
# 2048    1300022230002720202021S0247400  data.gouv.fr_aife  20202021S0247400
# ...                                ...                ...               ...
# 231121  7760564670058720192019F2523500  data.gouv.fr_aife  20192019F2523500
# 231631  7760564670058720202020S1484200  data.gouv.fr_aife  20202020S1484200
# 231647  7760564670058720182019F0600200  data.gouv.fr_aife  20182019F0600200
# 231650  7760564670058720192019F2523300  data.gouv.fr_aife  20192019F2523300
# 232443  7760564670058720202020F0111800  data.gouv.fr_aife  20202020F0111800
#
#           type        nature              procedure  \
# 119     Marché        Marché  Appel d'offres ouvert
# 703     Marché  Accord-cadre  Appel d'offres ouvert
# 1408    Marché  Accord-cadre  Appel d'offres ouvert
# 1463    Marché  Accord-cadre                   None
# 2048    Marché  Accord-cadre  Appel d'offres ouvert
# ...        ...           ...                    ...
# 231121  Marché  Accord-cadre  Appel d'offres ouvert
# 231631  Marché  Accord-cadre                   None
# 231647  Marché  Accord-cadre  Appel d'offres ouvert
# 231650  Marché  Accord-cadre  Appel d'offres ouvert
# 232443  Marché  Accord-cadre  Appel d'offres ouvert
#
#                                                     objet   codecpv  \
# 119     Le projet consiste en la mise à 2x2 voies de l...  45233100
# 703     Travaux d'entretien des chaussées de la DIR Ouest  45233139
# 1408    Travaux d'entretien des chaussées de la DIR Ouest  45233139
# 1463    Conception, Construction, Aménagement, Entreti...  45212410
# 2048    GCS UniHA - Marché public de maintenance en im...  50421000
# ...                                                   ...       ...
# 231121  Véhicules de transport en commun de type autob...  34121000
# 231631     Services d’informatique en nuage (IaaS / PaaS)  72500000
# 231647  Fourniture d'éléments d'infrastructures inform...  48822000
# 231650  Véhicules de transport en commun de type autob...  34121000
# 232443  Fourniture de véhicules industriels «porteurs ...  34139000
#
#         dureemois datenotification datepublicationdonnees       montant  \
# 119           576       2020-03-15             2020-03-15  3.952233e+09
# 703            48       2020-03-05             2020-03-05  1.000000e+08
# 1408           48       2020-03-05             2020-03-05  1.000000e+08
# 1463           48       2020-06-17             2020-06-17  1.020000e+08
# 2048           72       2020-12-20             2020-12-20  4.296000e+08
# ...           ...              ...                    ...           ...
# 231121         48       2019-12-09             2019-12-09  1.717088e+08
# 231631         48       2020-01-23             2020-01-23  2.500000e+08
# 231647         48       2018-12-10             2018-12-10  2.040000e+08
# 231650         48       2019-12-09             2019-12-09  1.817088e+08
# 232443         48       2020-03-01             2020-03-01  2.000000e+08
#
#         formeprix     acheteur_id  \
# 119         Ferme  11000201100044
# 703          None  13000170400589
# 1408         None  13000170400589
# 1463    Révisable  13000190200019
# 2048         None  13000222300027
# ...           ...             ...
# 231121  Révisable  77605646700587
# 231631  Révisable  77605646700587
# 231647  Révisable  77605646700587
# 231650  Révisable  77605646700587
# 232443  Révisable  77605646700587
#
#                                             acheteur_name
# 119     Ministère de la Transition Écologique, Ministè...
# 703     Ministère de la Transition écologique et solid...
# 1408    Ministère de la Transition écologique et solid...
# 1463    Ministère des armées - Service d'Infrastructur...
# 2048                                           GCS UNIHA
# ...                                                   ...
# 231121                       Département Assistanat Achat
# 231631  Union des Groupements d'Achats Publics - Dépar...
# 231647         Union des Groupements d'Achats Publics -
# 231650  Union des Groupements d'Achats Publics - Dépar...
# 232443  Union des Groupements d'Achats Publics - Dépar...
#
# [464 rows x 15 columns]

# %% [markdown]
# 100 million euros for a routine infrastructure project? Or buses? I keep those value in the reporting value as it highlights data quality issues, and could be legit, but would also include a flag "suspicious amount"

# %%
marches.loc[marches['montant']==0]
# Out:
#                               decp_uid             source           decp_id  \
# 783     1300015300033120182020S0858500  data.gouv.fr_aife  20182020S0858500
# 1380    1300050100002520182020F0290300   atexo-maximilien  20182020F0290300
# 1383    1300050100002520192020F0278100   atexo-maximilien  20192020F0278100
# 1855    1300050100002520182020F0271800   atexo-maximilien  20182020F0271800
# 1858    1300050100002520192020F0274200   atexo-maximilien  20192020F0274200
# ...                                ...                ...               ...
# 232024  7834366600002220194SG1RuS4ky00  data.gouv.fr_aife  20194SG1RuS4ky00
# 232027  783436660000222019fn9ZRCSvNc00  data.gouv.fr_aife  2019fn9ZRCSvNc00
# 232088  8349834390001120192020S0027400   atexo-maximilien  20192020S0027400
# 232380  775665599001292019hToZm4SeD900  data.gouv.fr_aife  2019hToZm4SeD900
# 232513  783436660000222018LhyxBoJIO700  data.gouv.fr_aife  2018LhyxBoJIO700
#
#           type        nature              procedure  \
# 783     Marché  Accord-cadre  Appel d'offres ouvert
# 1380    Marché  Accord-cadre  Appel d'offres ouvert
# 1383    Marché  Accord-cadre  Appel d'offres ouvert
# 1855    Marché  Accord-cadre  Appel d'offres ouvert
# 1858    Marché  Accord-cadre  Appel d'offres ouvert
# ...        ...           ...                    ...
# 232024  Marché        Marché      Procédure adaptée
# 232027  Marché        Marché      Procédure adaptée
# 232088  Marché  Accord-cadre      Procédure adaptée
# 232380  Marché  Accord-cadre      Procédure adaptée
# 232513  Marché        Marché      Procédure adaptée
#
#                                                     objet   codecpv  \
# 783     Prestations de gestion de flotte pour véhicule...  50111100
# 1380    Fourniture, la mise en service et la maintenan...  33152000
# 1383    L’acquisition et/ou la location avec option d’...  33100000
# 1855    Lot 6 - Serviettes périodiques - Fourniture de...  33771100
# 1858    Fourniture de produits surgelés, de potages dé...  15000000
# ...                                                   ...       ...
# 232024                  20190611 3204-Rev�tements de sols  45000000
# 232027                       20190221 3143-ASSAINISSEMENT  45000000
# 232088  La présente consultation a pour objet de concl...  79417000
# 232380  2019-130 -2019-130 : R�daction des comptes ren...  79551000
# 232513            20181218 3102-LOT 04 COUVERTURE BARDAGE  45000000
#
#         dureemois datenotification datepublicationdonnees  montant  \
# 783            48       2018-07-20             2018-07-20      0.0
# 1380           48       2018-11-05             2018-11-05      0.0
# 1383           48       2019-06-12             2019-06-12      0.0
# 1855           48       2018-07-30             2018-07-30      0.0
# 1858           48       2019-03-26             2019-03-26      0.0
# ...           ...              ...                    ...      ...
# 232024          8       2019-09-18             2019-10-22      0.0
# 232027        999       2019-06-27             2019-10-22      0.0
# 232088         48       2019-01-21             2019-01-21      0.0
# 232380         12       2019-08-09             2019-11-13      0.0
# 232513        999       2019-06-28             2019-10-22      0.0
#
#                     formeprix     acheteur_id  \
# 783                 Révisable  13000153000331
# 1380                Révisable  13000501000025
# 1383    Ferme et actualisable  13000501000025
# 1855                Révisable  13000501000025
# 1858                Révisable  13000501000025
# ...                       ...             ...
# 232024              Révisable  78343666000022
# 232027                  Ferme  78343666000022
# 232088                  Ferme  83498343900011
# 232380              Révisable  77566559900129
# 232513                  Ferme  78343666000022
#
#                                             acheteur_name
# 783     Ministère de la Transition Écologique et Solid...
# 1380                  RESEAUX DES ACHETEURS HOSPITALIERS
# 1383                  RESEAUX DES ACHETEURS HOSPITALIERS
# 1855                  RESEAUX DES ACHETEURS HOSPITALIERS
# 1858                  RESEAUX DES ACHETEURS HOSPITALIERS
# ...                                                   ...
# 232024                                           VOSGELIS
# 232027                                           VOSGELIS
# 232088                                        PARIS 2024
# 232380                  AGENCE FRANCAISE DE DEVELOPPEMENT
# 232513                                           VOSGELIS
#
# [1046 rows x 15 columns]

# %% [markdown]
# Those two contracts are `type` = `Accord-cadre`, or framework, which means that no Purchase Order is actually sent, but rather the future prices are agreed.

# %% [markdown]
# ### Date

# %%
marches['datenotification'] = pd.to_datetime(marches['datenotification'], errors='coerce' )

# %%
marches['datenotification'].isnull().sum()/marches.shape[0]
# Out:
# 0.010995151473470651

# %%
marches['datenotification'].describe()
# Out:
# count                  230090
# unique                   1401
# top       2019-12-20 00:00:00
# freq                     1071
# first     2003-10-24 00:00:00
# last      2202-12-24 00:00:00
# Name: datenotification, dtype: object

# %% [markdown]
# Looking for strange prehistoric or futuristic date ;)
# Found one in 2202??

# %%
import datetime
marches.loc[marches['datenotification'].dt.year> 2021]
# Out:
#                               decp_uid             source           decp_id  \
# 72577     2175000160001920201310090029  data.gouv.fr_aife    20201310090029
# 79991   219400223000182019BVRvozx1-y00  data.gouv.fr_aife  2019BVRvozx1-y00
# 89870   219400223000182019bUQhJCdsVg00  data.gouv.fr_aife  2019bUQhJCdsVg00
# 105909    2175000160967120212021S00786  data.gouv.fr_aife    20212021S00786
# 163902  256701152000252020T0161APACN00   data.gouv.fr_pes  2020T0161APACN00
# 203966  219400223000182019n_ZqwpLBIS00  data.gouv.fr_aife  2019n_ZqwpLBIS00
#
#           type        nature                   procedure  \
# 72577   Marché        Marché  Procédure avec négociation
# 79991   Marché  Accord-cadre       Appel d'offres ouvert
# 89870   Marché  Accord-cadre           Procédure adaptée
# 105909  Marché        Marché           Procédure adaptée
# 163902  Marché  Accord-cadre           Procédure adaptée
# 203966  Marché  Accord-cadre       Appel d'offres ouvert
#
#                                                     objet     codecpv  \
# 72577   PRESTATIONS DE VISITES EN PRÉSENCE DE TIERS PO...    85311300
# 79991   2019 - MOBILIERS ECOLE-Lot 3 : Fourniture de m...    39160000
# 89870   2019 - DENREES PETITE ENFANCE-Lot 2 Viandes fr...    15800000
# 105909  REALISATION IMPRESSION DIFFUSION INFO 15 FINAN...    79800000
# 163902  ACBC TRAV ASST REGION STRASBOURG NORD PAR MAD ...  45520000-8
# 203966                   2019 - HORTICOLES-Lot 3 Arbustes     3121000
#
#         dureemois datenotification datepublicationdonnees    montant  \
# 72577          33       2023-10-27             2020-10-30   150000.0
# 79991          12       2106-06-06             2019-09-13     3000.0
# 89870          12       2109-09-17             2019-11-15    10000.0
# 105909         12       2022-03-05             2021-03-12   214000.0
# 163902         47       2202-12-24             2020-08-12  1679135.0
# 203966         12       2109-07-11             2019-09-13    15000.0
#
#         formeprix     acheteur_id                          acheteur_name
# 72577   Révisable  21750001600019        VILLE DE PARIS BUDGET PRINCIPAL
# 79991   Révisable  21940022300018                Mairie de Choisy Le Roi
# 89870   Révisable  21940022300018                Mairie de Choisy Le Roi
# 105909      Ferme  21750001609671         MAIRIE DU 15EME ARRONDISSEMENT
# 163902  Révisable  25670115200025  SM EAUX ASSAINISSEMENT ALSACE MOSELLE
# 203966  Révisable  21940022300018                Mairie de Choisy Le Roi

# %% [markdown]
# strange dates.. As usual, keeping them and perhaps putting a flag on those strange dates

# %%
def convert_yearmonth(d):
    """ convert date to string on this format yyyy-mm"""
    return str(d.year).split('.')[0] + '-' + str(d.month).split('.')[0].zfill(2)

# %%
n_per_yearmonth = marches['datenotification'].loc[
    (marches['datenotification'].dt.year >=2018) & 
    (marches['datenotification'].dt.year <=2021)
].apply(convert_yearmonth).value_counts().sort_index()

# %%
fig = plt.figure(figsize=(30,4))
ax = fig.add_axes([0,0,1,1])
ax.bar(n_per_yearmonth.index, n_per_yearmonth.values);

# %% [markdown]
# - the number of contracts before 2019 is pretty low, which is consistent with the new directives on open data not yet rolled out.
# - interestingly, we see a lot of seasonal variation with a peak of contracts being signed in december and july/august, which can be interpreted as people signing a contract to utilize the budget (december) and before the holidays (july/august)
# - We will do more data visualization in ad-hoc dashboards

# %%
marches['datepublicationdonnees'] = pd.to_datetime(marches['datepublicationdonnees'])
marches['datepublicationdonnees'].describe()
# Out:
# count                  232644
# unique                   1220
# top       2020-04-07 00:00:00
# freq                     1916
# first     1980-11-22 00:00:00
# last      2021-11-24 00:00:00
# Name: datepublicationdonnees, dtype: object

# %%
n_per_yearmonth2 = marches['datepublicationdonnees'].apply(convert_yearmonth).value_counts().sort_index()
fig = plt.figure(figsize=(30,4))
ax = fig.add_axes([0,0,1,1])
ax.bar(n_per_yearmonth2.index, n_per_yearmonth2.values);

# %% [markdown]
# The data is published at regular intervals, tracking the peak in notification described above. It would be interesting to calculate the mean lag between notification and publication of the data
